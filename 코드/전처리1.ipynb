# %%
import pandas as pd

# %%
df1=pd.read_excel('서울특별시 등록학원 정보 (2017.12.).xls',sheet_name='동부(동대문구,중랑구)')
df2=pd.read_excel('서울특별시 등록학원 정보 (2017.12.).xls',sheet_name='서부(은평구,서대문구,마포구)')
df3=pd.read_excel('서울특별시 등록학원 정보 (2017.12.).xls',sheet_name='남부(영등포구,구로구,금천구)')
df4=pd.read_excel('서울특별시 등록학원 정보 (2017.12.).xls',sheet_name='북부(노원구,도봉구)')
df5=pd.read_excel('서울특별시 등록학원 정보 (2017.12.).xls',sheet_name='중부(종로구,중구,용산구)')
df6=pd.read_excel('서울특별시 등록학원 정보 (2017.12.).xls',sheet_name='성북강북(성북구,강북구)')
df7=pd.read_excel('서울특별시 등록학원 정보 (2017.12.).xls',sheet_name='강서양천(강서구,양천구)')
df8=pd.read_excel('서울특별시 등록학원 정보 (2017.12.).xls',sheet_name='강동송파(강동구,송파구)')
df9=pd.read_excel('서울특별시 등록학원 정보 (2017.12.).xls',sheet_name='강남서초(강남구,서초구)')
df10=pd.read_excel('서울특별시 등록학원 정보 (2017.12.).xls',sheet_name='동작관악(동작구,관악구)')
df11=pd.read_excel('서울특별시 등록학원 정보 (2017.12.).xls',sheet_name='성동광진(성동구,광진구)')

# %%
df=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11])
# Out:
# /usr/local/var/pyenv/versions/anaconda3-2019.03/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df1=pd.read_excel('서울특별시 등록학원 정보 (2017.12.).xls',sheet_name='동부(동대문구,중랑구)')

# %%
df.to_csv('합침.csv')

# %%
df
# Out:
#      Unnamed: 22 강사수    교습계열                                  교습과목(반)  교습과정  \
# 0            NaN   1  산업응용기술                                     이발기술  이·미용
# 1            NaN   6     NaN                                   전산회계1급   NaN
# 2            NaN   6     NaN                                   전산세무2급   NaN
# 3            NaN   6     NaN                           전산세무1급(법인세무조정)   NaN
# 4            NaN   6     NaN  (초급,중급)전산회계1급 및 전산세무2급 자격증반(케이렙+더존(AT))   NaN
# 5            NaN   6     NaN        (초급,중급)전산세무회계 종합반(자격증+실무)(케이렙+더존)   NaN
# 6            NaN   6     NaN                    전산회계1급 및 전산세무2급 자격취득반   NaN
# 7            NaN   6     NaN                               (더존)전산세무회계   NaN
# 8            NaN   6     NaN                                 전산세무회계취득   NaN
# 9            NaN   6     NaN                              전산세무 및 회계양성   NaN
# 10           NaN   6     NaN                             전산세무1급 자격취득반   NaN
# ...
